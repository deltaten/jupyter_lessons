# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %% [markdown]
# ## как отрисовать простой график зависимости зарплаты от даты 6 способов

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
plt.plot(df.index, df.income)

# %%
df.income.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Вам дан датасэт с 2-мя фичами (колонками). Постройте график распределения точек (наблюдений) в пространстве этих 2-ух переменных (одна из них будет x, а другая - y) и напишите число кластеров, формируемых наблюдениями.

# %%
df2 = pd.read_csv('dataset_209770_6.txt', sep=' ')

# %%
df2
# Out:
#               x            y
# 0    797.380106  1306.159329
# 1   1304.255626   607.894646
# 2     95.125436   188.673471
# 3    800.807355  1299.319058
# 4    394.944826  1197.035348
# ..          ...          ...
# 75   710.503714  1107.160720
# 76   896.010167   706.296334
# 77   190.426126   909.820721
# 78   900.719796   698.571577
# 79   404.908192  1187.600084
#
# [80 rows x 2 columns]

# %%
df2.plot.scatter(x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# ## постройте тепловую карту, чтобы различия было видно наглядно

# %%
genome_matrix = pd.read_csv('genome_matrix.csv', index_col=0)

# %%
genome_matrix
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(genome_matrix, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)
